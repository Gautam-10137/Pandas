# %% [markdown]
# ## useful methods

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('tips.csv')

# %%
str(122345678)[-4:]  # extracting last 4 digits using slicing in python
# Out:
# '5678'

# %%
# Pandas.apply allow the users to pass a function and apply it on every single value of the Pandas series.
def round_num(num):
    return round(num)

# %%
df['roundOff']=df['total_bill'].apply(round_num) # here apply func. should return a single value(since, have to put in 1 col )

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  roundOff
# 0         16.99  1.01  Female     No   Sun  Dinner     2        17
# 1         10.34  1.66    Male     No   Sun  Dinner     3        10
# 2         21.01  3.50    Male     No   Sun  Dinner     3        21
# 3         23.68  3.31    Male     No   Sun  Dinner     2        24
# 4         24.59  3.61  Female     No   Sun  Dinner     4        25
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        29
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        27
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        23
# 242       17.82  1.75    Male     No   Sat  Dinner     2        18
# 243       18.78  3.00  Female     No  Thur  Dinner     2        19
#
# [244 rows x 8 columns]

# %%
#  adding reviews like how costlier the restaurant is
def review(price):
    if price<10:
        return '$'
    elif price>=10 and price<30:
        return '$$'
    else:
        return '$$$'

# %%
df['costly']=df['total_bill'].apply(review)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  roundOff costly
# 0         16.99  1.01  Female     No   Sun  Dinner     2        17     $$
# 1         10.34  1.66    Male     No   Sun  Dinner     3        10     $$
# 2         21.01  3.50    Male     No   Sun  Dinner     3        21     $$
# 3         23.68  3.31    Male     No   Sun  Dinner     2        24     $$
# 4         24.59  3.61  Female     No   Sun  Dinner     4        25     $$
# ..          ...   ...     ...    ...   ...     ...   ...       ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        29     $$
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        27     $$
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        23     $$
# 242       17.82  1.75    Male     No   Sat  Dinner     2        18     $$
# 243       18.78  3.00  Female     No  Thur  Dinner     2        19     $$
#
# [244 rows x 9 columns]

# %%
df[df['costly']=='$$$']
# Out:
#      total_bill    tip     sex smoker   day    time  size  roundOff costly
# 11        35.26   5.00  Female     No   Sun  Dinner     4        35    $$$
# 23        39.42   7.58    Male     No   Sat  Dinner     4        39    $$$
# 39        31.27   5.00    Male     No   Sat  Dinner     3        31    $$$
# 44        30.40   5.60    Male     No   Sun  Dinner     4        30    $$$
# 47        32.40   6.00    Male     No   Sun  Dinner     4        32    $$$
# 52        34.81   5.20  Female     No   Sun  Dinner     4        35    $$$
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4        38    $$$
# 59        48.27   6.73    Male     No   Sat  Dinner     4        48    $$$
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2        33    $$$
# 85        34.83   5.17  Female     No  Thur   Lunch     4        35    $$$
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4        40    $$$
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3        44    $$$
# 112       38.07   4.00    Male     No   Sun  Dinner     3        38    $$$
# 141       34.30   6.70    Male     No  Thur   Lunch     6        34    $$$
# 142       41.19   5.00    Male     No  Thur   Lunch     5        41    $$$
# 156       48.17   5.00    Male     No   Sun  Dinner     6        48    $$$
# 167       31.71   4.50    Male     No   Sun  Dinner     4        32    $$$
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3        51    $$$
# 173       31.85   3.18    Male    Yes   Sun  Dinner     2        32    $$$
# 175       32.90   3.11    Male    Yes   Sun  Dinner     2        33    $$$
# 179       34.63   3.55    Male    Yes   Sun  Dinner     2        35    $$$
# 180       34.65   3.68    Male    Yes   Sun  Dinner     4        35    $$$
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3        45    $$$
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2        41    $$$
# 187       30.46   2.00    Male    Yes   Sun  Dinner     5        30    $$$
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4        43    $$$
# 207       38.73   3.00    Male    Yes   Sat  Dinner     4        39    $$$
# 210       30.06   2.00    Male    Yes   Sat  Dinner     3        30    $$$
# 212       48.33   9.00    Male     No   Sat  Dinner     4        48    $$$
# 219       30.14   3.09  Female    Yes   Sat  Dinner     4        30    $$$
# 237       32.83   1.17    Male    Yes   Sat  Dinner     2        33    $$$
# 238       35.83   4.67  Female     No   Sat  Dinner     3        36    $$$

# %%
#  custom functions using multiple columns as inputs

# %%
# using lambda function
df['total_bill'].apply(lambda bill: bill*2)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
def quality(total_bill,tip):
    if tip/total_bill > 0.25:
        return "Generous"
    else:
        return "Other"

# %%
quality(16.99,1.01)
# Out:
# 'Other'

# %%
df['Quality']=df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)

# %%
df['Quality']=np.vectorize(quality)(df['total_bill'],df['tip']) 
# .vectorize is making func. quality to be aware of numpy function & hence can be used as numpy func. like mean

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  roundOff costly  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2        17     $$
# 1         10.34  1.66    Male     No   Sun  Dinner     3        10     $$
# 2         21.01  3.50    Male     No   Sun  Dinner     3        21     $$
# 3         23.68  3.31    Male     No   Sun  Dinner     2        24     $$
# 4         24.59  3.61  Female     No   Sun  Dinner     4        25     $$
# ..          ...   ...     ...    ...   ...     ...   ...       ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        29     $$
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        27     $$
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        23     $$
# 242       17.82  1.75    Male     No   Sat  Dinner     2        18     $$
# 243       18.78  3.00  Female     No  Thur  Dinner     2        19     $$
#
#     Quality
# 0     Other
# 1     Other
# 2     Other
# 3     Other
# 4     Other
# ..      ...
# 239   Other
# 240   Other
# 241   Other
# 242   Other
# 243   Other
#
# [244 rows x 10 columns]

# %%
# comparing efficiency
import timeit

# %%
# code snippet to be executed once
setup = '''
import numpy as np
import pandas as pd
df=pd.read_csv('tips.csv')
def quality(total_bill,tip):
   if tip/total_bill > 0.25:
        return "Generous"
   else:
        return "Other"
'''

# %%
#  code snippet whose execution time is to be measured
stmt_one='''
df['tip_quality']=df[['total_bill','tip']].apply(lambda df:quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two='''
df['tip_quality']=np.vectorize(quality)(df['total_bill'],df['tip'])
'''

# %%
timeit.timeit(stmt=stmt_two,setup=setup,number=1000)
# Out:
# 0.15499359999995477

# %%
timeit.timeit(stmt=stmt_one,setup=setup,number=1000)
# Out:
# 1.4373065000000338

# %% [markdown]
# ## Statistical inf. & sorting

# %%
#  sorting 
df.sort_values('tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  roundOff costly  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1         3      $
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2        13     $$
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2         6      $
# 111        7.25   1.00  Female     No   Sat  Dinner     1         7      $
# 0         16.99   1.01  Female     No   Sun  Dinner     2        17     $$
# ..          ...    ...     ...    ...   ...     ...   ...       ...    ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6        34    $$$
# 59        48.27   6.73    Male     No   Sat  Dinner     4        48    $$$
# 23        39.42   7.58    Male     No   Sat  Dinner     4        39    $$$
# 212       48.33   9.00    Male     No   Sat  Dinner     4        48    $$$
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3        51    $$$
#
#       Quality
# 67   Generous
# 236     Other
# 92      Other
# 111     Other
# 0       Other
# ..        ...
# 141     Other
# 59      Other
# 23      Other
# 212     Other
# 170     Other
#
# [244 rows x 10 columns]

# %%
df.sort_values('tip',ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  roundOff costly  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3        51    $$$
# 212       48.33   9.00    Male     No   Sat  Dinner     4        48    $$$
# 23        39.42   7.58    Male     No   Sat  Dinner     4        39    $$$
# 59        48.27   6.73    Male     No   Sat  Dinner     4        48    $$$
# 141       34.30   6.70    Male     No  Thur   Lunch     6        34    $$$
# ..          ...    ...     ...    ...   ...     ...   ...       ...    ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2        17     $$
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2        13     $$
# 111        7.25   1.00  Female     No   Sat  Dinner     1         7      $
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1         3      $
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2         6      $
#
#       Quality
# 170     Other
# 212     Other
# 23      Other
# 59      Other
# 141     Other
# ..        ...
# 0       Other
# 236     Other
# 111     Other
# 67   Generous
# 92      Other
#
# [244 rows x 10 columns]

# %%
df.sort_values(['tip','size']) # firstly by tip , then by size
# Out:
#      total_bill    tip     sex smoker   day    time  size  roundOff costly  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1         3      $
# 111        7.25   1.00  Female     No   Sat  Dinner     1         7      $
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2         6      $
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2        13     $$
# 0         16.99   1.01  Female     No   Sun  Dinner     2        17     $$
# ..          ...    ...     ...    ...   ...     ...   ...       ...    ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6        34    $$$
# 59        48.27   6.73    Male     No   Sat  Dinner     4        48    $$$
# 23        39.42   7.58    Male     No   Sat  Dinner     4        39    $$$
# 212       48.33   9.00    Male     No   Sat  Dinner     4        48    $$$
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3        51    $$$
#
#       Quality
# 67   Generous
# 111     Other
# 92      Other
# 236     Other
# 0       Other
# ..        ...
# 141     Other
# 59      Other
# 23      Other
# 212     Other
# 170     Other
#
# [244 rows x 10 columns]

# %%
# index of min,max value
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df.iloc[170]
# Out:
# total_bill     50.81
# tip             10.0
# sex             Male
# smoker           Yes
# day              Sat
# time          Dinner
# size               3
# roundOff          51
# costly           $$$
# Quality        Other
# Name: 170, dtype: object

# %%
df.iloc[df['tip'].idxmin()]
# Out:
# total_bill        3.07
# tip                1.0
# sex             Female
# smoker             Yes
# day                Sat
# time            Dinner
# size                 1
# roundOff             3
# costly               $
# Quality       Generous
# Name: 67, dtype: object

# %%
df=pd.read_csv('tips.csv')

# %%
#  correlation of columns    (pearson correlation coefficient)
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# counts of unique values
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
# unique values
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
# no. of unique values
df['day'].nunique()
# Out:
# 4

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
#  Replacing values
df['sex'].replace(['Female','Male'],['F','M'])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
#  changing by doing mapping
my_map={'Female':'F','Male':'M'}      # easy to maintain on large scale

# %%
df['sex'].map(my_map)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
#  to know if rows are duplicated
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
simple_df=pd.DataFrame({'a':[1,2,2],'b':[1,3,3]})

# %%
simple_df
# Out:
#    a  b
# 0  1  1
# 1  2  3
# 2  2  3

# %%
simple_df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
#  dropping duplicates[]
simple_df.drop_duplicates()
# Out:
#    a  b
# 0  1  1
# 1  2  3

# %%
df[df['total_bill'].between(10,20,inclusive='both')]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [130 rows x 7 columns]

# %%
#  n largest value rows
df.nlargest(10,'tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 239       29.03   5.92    Male     No   Sat  Dinner     3
# 88        24.71   5.85    Male     No  Thur   Lunch     2

# %%
#  similar
df.sort_values('tip',ascending=False).iloc[0:10]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 239       29.03   5.92    Male     No   Sat  Dinner     3
# 88        24.71   5.85    Male     No  Thur   Lunch     2

# %%
#  picking up random samples
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 134       18.26  3.25  Female     No  Thur   Lunch     2
# 165       24.52  3.48    Male     No   Sun  Dinner     3
# 173       31.85  3.18    Male    Yes   Sun  Dinner     2
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2

# %%
df.sample(frac=0.1)     # 10%  of total (useful in picking up test _data_set)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 138       16.00  2.00    Male    Yes  Thur   Lunch     2
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 154       19.77  2.00    Male     No   Sun  Dinner     4
# 30         9.55  1.45    Male     No   Sat  Dinner     2
# 43         9.68  1.32    Male     No   Sun  Dinner     2
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2
# 89        21.16  3.00    Male     No  Thur   Lunch     2
# 61        13.81  2.00    Male    Yes   Sat  Dinner     2
# 46        22.23  5.00    Male     No   Sun  Dinner     2
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 86        13.03  2.00    Male     No  Thur   Lunch     2
# 195        7.56  1.44    Male     No  Thur   Lunch     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 184       40.55  3.00    Male    Yes   Sun  Dinner     2
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 123       15.95  2.00    Male     No  Thur   Lunch     2
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 70        12.02  1.97    Male     No   Sat  Dinner     2
